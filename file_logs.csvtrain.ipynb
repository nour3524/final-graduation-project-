# %%
import pandas as pd

# %%
df = pd.read_csv("data/file_logs.csv")
df.head()
# Out:
#              timestamp                                      file_name  \
# 0  2025-01-16T15:09:06                C:\Users\bob\Music\playlist.m3u
# 1  2025-01-25T06:51:25               C:\Users\alice\Desktop\notes.txt
# 2  2025-01-08T00:11:09  C:\Program Files\Microsoft Office\winword.exe
# 3  2025-01-05T18:43:33               C:\Users\alice\Desktop\notes.txt
# 4  2025-01-26T10:47:53           C:\Users\admin\Documents\report.docx
#
#   access_type     user   label                  reason
# 0       Write    alice  benign  Legitimate file access
# 1      Delete     jdoe  benign  Legitimate file access
# 2        Read  charlie  benign  Legitimate file access
# 3      Delete      eve  benign  Legitimate file access
# 4       Write      eve  benign  Legitimate file access

# %%
df['label'] = df.apply(lambda row: 'benign' if row['label'] == 'benign' else row['reason'], axis=1)

# %%
df.tail(50)
# Out:
#                  timestamp                                      file_name  \
# 99950  2025-01-07T07:31:42            C:\Users\jdoe\Desktop\passwords.txt
# 99951  2025-01-29T15:41:31                C:\Users\bob\Music\playlist.m3u
# 99952  2025-01-21T14:27:36               C:\Users\alice\Desktop\notes.txt
# 99953  2025-01-30T14:37:23              C:\Windows\System32\drivers\hosts
# 99954  2025-01-25T21:37:40      C:\Users\jdoe\Downloads\presentation.pptx
# 99955  2025-01-13T11:24:34               C:\Users\alice\Desktop\notes.txt
# 99956  2025-01-10T06:26:34           C:\Users\admin\Documents\report.docx
# 99957  2025-01-12T01:08:12           C:\Users\admin\Documents\report.docx
# 99958  2025-01-14T17:54:19               C:\Users\alice\Desktop\notes.txt
# 99959  2025-01-09T16:04:29  C:\Program Files\Microsoft Office\winword.exe
# 99960  2025-01-04T11:43:38           C:\Users\charlie\AppData\malware.exe
# 99961  2025-01-18T07:06:11           C:\Users\charlie\AppData\malware.exe
# 99962  2025-01-02T06:31:01        C:\Users\eve\Downloads\hacking_tool.zip
# 99963  2025-01-28T08:03:44               C:\Users\alice\Desktop\notes.txt
# 99964  2025-01-27T23:15:48            C:\Users\jdoe\Desktop\passwords.txt
# 99965  2025-01-25T22:59:04                C:\Users\bob\Music\playlist.m3u
# 99966  2025-01-01T08:38:16              C:\Windows\System32\drivers\hosts
# 99967  2025-01-12T03:52:58            C:\Users\jdoe\Desktop\passwords.txt
# 99968  2025-01-04T17:42:38           C:\Users\admin\Documents\report.docx
# 99969  2025-01-05T13:33:48            C:\Users\jdoe\Desktop\passwords.txt
# 99970  2025-01-20T16:30:16           C:\Users\charlie\AppData\malware.exe
# 99971  2025-01-14T20:56:35        C:\Users\eve\Downloads\hacking_tool.zip
# 99972  2025-01-10T10:09:09           C:\Users\charlie\AppData\malware.exe
# 99973  2025-01-17T23:18:36              C:\Windows\System32\drivers\hosts
# 99974  2025-01-28T15:20:54           C:\Users\charlie\AppData\malware.exe
# 99975  2025-01-04T20:50:28                C:\Users\bob\Music\playlist.m3u
# 99976  2025-01-06T13:49:37  C:\Program Files\Microsoft Office\winword.exe
# 99977  2025-01-06T07:06:56              C:\Windows\System32\drivers\hosts
# 99978  2025-01-19T05:48:20              C:\Windows\System32\drivers\hosts
# 99979  2025-01-21T04:35:38      C:\Users\jdoe\Downloads\presentation.pptx
# 99980  2025-01-22T05:37:41           C:\Users\charlie\AppData\malware.exe
# 99981  2025-01-26T23:01:17           C:\Users\charlie\AppData\malware.exe
# 99982  2025-01-19T09:24:05           C:\Users\admin\Documents\report.docx
# 99983  2025-01-06T15:14:02  C:\Program Files\Microsoft Office\winword.exe
# 99984  2025-01-05T19:52:08              C:\Windows\System32\drivers\hosts
# 99985  2025-01-25T15:10:51              C:\Windows\System32\drivers\hosts
# 99986  2025-01-11T17:45:21               C:\Users\alice\Desktop\notes.txt
# 99987  2025-01-30T09:20:21            C:\Users\jdoe\Desktop\passwords.txt
# 99988  2025-01-01T12:25:12  C:\Program Files\Microsoft Office\winword.exe
# 99989  2025-01-07T20:12:57                C:\Users\bob\Music\playlist.m3u
# 99990  2025-01-24T12:38:04                C:\Users\bob\Music\playlist.m3u
# 99991  2025-01-10T00:43:41            C:\Users\jdoe\Desktop\passwords.txt
# 99992  2025-01-16T23:39:17                C:\Users\bob\Music\playlist.m3u
# 99993  2025-01-28T22:41:52           C:\Users\admin\Documents\report.docx
# 99994  2025-01-10T10:32:24           C:\Users\charlie\AppData\malware.exe
# 99995  2025-01-23T11:45:34           C:\Users\charlie\AppData\malware.exe
# 99996  2025-01-24T22:29:01      C:\Users\admin\Documents\confidential.pdf
# 99997  2025-01-28T15:06:28            C:\Users\jdoe\Desktop\passwords.txt
# 99998  2025-01-12T08:36:07               C:\Users\alice\Desktop\notes.txt
# 99999  2025-01-06T16:49:18           C:\Users\charlie\AppData\malware.exe
#
#       access_type        user  \
# 99950        Move         eve
# 99951        Move         bob
# 99952        Read         bob
# 99953        Copy  admin_user
# 99954        Move         bob
# 99955      Delete         eve
# 99956       Write         eve
# 99957        Move         eve
# 99958      Delete     charlie
# 99959      Delete     charlie
# 99960      Delete       alice
# 99961     Execute         eve
# 99962       Write         bob
# 99963        Move         eve
# 99964     Execute         eve
# 99965        Copy        jdoe
# 99966        Read        jdoe
# 99967       Write     charlie
# 99968       Write       alice
# 99969     Execute        jdoe
# 99970        Copy        jdoe
# 99971        Move         bob
# 99972        Copy  admin_user
# 99973        Move       alice
# 99974       Write  admin_user
# 99975       Write     charlie
# 99976        Move        jdoe
# 99977        Move         eve
# 99978        Copy         eve
# 99979     Execute       alice
# 99980      Delete         bob
# 99981        Read     charlie
# 99982      Delete     charlie
# 99983      Delete  admin_user
# 99984        Read        jdoe
# 99985      Delete  admin_user
# 99986      Delete  admin_user
# 99987      Delete         eve
# 99988        Copy         bob
# 99989        Read  admin_user
# 99990        Move        jdoe
# 99991       Write     charlie
# 99992       Write         eve
# 99993       Write         eve
# 99994      Delete         eve
# 99995     Execute  admin_user
# 99996      Delete       alice
# 99997        Copy       alice
# 99998     Execute        jdoe
# 99999        Move         bob
#
#                                                  label  \
# 99950    Unusual file movement or modification pattern
# 99951         Repeated access to system-critical files
# 99952         Repeated access to system-critical files
# 99953    Unusual file movement or modification pattern
# 99954   Frequent access to files outside working hours
# 99955   Frequent access to files outside working hours
# 99956         Repeated access to system-critical files
# 99957         Repeated access to system-critical files
# 99958   Frequent access to files outside working hours
# 99959    Unusual file movement or modification pattern
# 99960    Unusual file movement or modification pattern
# 99961  Copying large amounts of data in a short period
# 99962         Repeated access to system-critical files
# 99963    Unusual file movement or modification pattern
# 99964         Repeated access to system-critical files
# 99965    Unusual file movement or modification pattern
# 99966    Unusual file movement or modification pattern
# 99967   Frequent access to files outside working hours
# 99968   Frequent access to files outside working hours
# 99969         Repeated access to system-critical files
# 99970         Repeated access to system-critical files
# 99971         Repeated access to system-critical files
# 99972         Repeated access to system-critical files
# 99973         Repeated access to system-critical files
# 99974   Frequent access to files outside working hours
# 99975   Frequent access to files outside working hours
# 99976   Frequent access to files outside working hours
# 99977    Unusual file movement or modification pattern
# 99978    Unusual file movement or modification pattern
# 99979  Copying large amounts of data in a short period
# 99980  Copying large amounts of data in a short period
# 99981  Copying large amounts of data in a short period
# 99982         Repeated access to system-critical files
# 99983  Copying large amounts of data in a short period
# 99984   Frequent access to files outside working hours
# 99985  Copying large amounts of data in a short period
# 99986    Unusual file movement or modification pattern
# 99987   Frequent access to files outside working hours
# 99988   Frequent access to files outside working hours
# 99989  Copying large amounts of data in a short period
# 99990  Copying large amounts of data in a short period
# 99991  Copying large amounts of data in a short period
# 99992         Repeated access to system-critical files
# 99993    Unusual file movement or modification pattern
# 99994  Copying large amounts of data in a short period
# 99995         Repeated access to system-critical files
# 99996    Unusual file movement or modification pattern
# 99997    Unusual file movement or modification pattern
# 99998   Frequent access to files outside working hours
# 99999         Repeated access to system-critical files
#
#                                                 reason
# 99950    Unusual file movement or modification pattern
# 99951         Repeated access to system-critical files
# 99952         Repeated access to system-critical files
# 99953    Unusual file movement or modification pattern
# 99954   Frequent access to files outside working hours
# 99955   Frequent access to files outside working hours
# 99956         Repeated access to system-critical files
# 99957         Repeated access to system-critical files
# 99958   Frequent access to files outside working hours
# 99959    Unusual file movement or modification pattern
# 99960    Unusual file movement or modification pattern
# 99961  Copying large amounts of data in a short period
# 99962         Repeated access to system-critical files
# 99963    Unusual file movement or modification pattern
# 99964         Repeated access to system-critical files
# 99965    Unusual file movement or modification pattern
# 99966    Unusual file movement or modification pattern
# 99967   Frequent access to files outside working hours
# 99968   Frequent access to files outside working hours
# 99969         Repeated access to system-critical files
# 99970         Repeated access to system-critical files
# 99971         Repeated access to system-critical files
# 99972         Repeated access to system-critical files
# 99973         Repeated access to system-critical files
# 99974   Frequent access to files outside working hours
# 99975   Frequent access to files outside working hours
# 99976   Frequent access to files outside working hours
# 99977    Unusual file movement or modification pattern
# 99978    Unusual file movement or modification pattern
# 99979  Copying large amounts of data in a short period
# 99980  Copying large amounts of data in a short period
# 99981  Copying large amounts of data in a short period
# 99982         Repeated access to system-critical files
# 99983  Copying large amounts of data in a short period
# 99984   Frequent access to files outside working hours
# 99985  Copying large amounts of data in a short period
# 99986    Unusual file movement or modification pattern
# 99987   Frequent access to files outside working hours
# 99988   Frequent access to files outside working hours
# 99989  Copying large amounts of data in a short period
# 99990  Copying large amounts of data in a short period
# 99991  Copying large amounts of data in a short period
# 99992         Repeated access to system-critical files
# 99993    Unusual file movement or modification pattern
# 99994  Copying large amounts of data in a short period
# 99995         Repeated access to system-critical files
# 99996    Unusual file movement or modification pattern
# 99997    Unusual file movement or modification pattern
# 99998   Frequent access to files outside working hours
# 99999         Repeated access to system-critical files

# %%
X = df.iloc[:, :-2]

Y = df["label"]

# %%
import pandas as pd

# Convert timestamp column to datetime format
X['timestamp'] = pd.to_datetime(X['timestamp'])

# Extract meaningful time-based features
X['hour'] = X['timestamp'].dt.hour  # Hour of the day (0-23)
X['minute'] = X['timestamp'].dt.minute  # Minute of the hour (0-59)
X['second'] = X['timestamp'].dt.second  # Second of the minute (0-59)


# Drop the original timestamp column (since it’s now numeric)
X = X.drop(columns=['timestamp'])

# %%
X
# Out:
#                                            file_name access_type        user  \
# 0                    C:\Users\bob\Music\playlist.m3u       Write       alice
# 1                   C:\Users\alice\Desktop\notes.txt      Delete        jdoe
# 2      C:\Program Files\Microsoft Office\winword.exe        Read     charlie
# 3                   C:\Users\alice\Desktop\notes.txt      Delete         eve
# 4               C:\Users\admin\Documents\report.docx       Write         eve
# ...                                              ...         ...         ...
# 99995           C:\Users\charlie\AppData\malware.exe     Execute  admin_user
# 99996      C:\Users\admin\Documents\confidential.pdf      Delete       alice
# 99997            C:\Users\jdoe\Desktop\passwords.txt        Copy       alice
# 99998               C:\Users\alice\Desktop\notes.txt     Execute        jdoe
# 99999           C:\Users\charlie\AppData\malware.exe        Move         bob
#
#        hour  minute  second
# 0        15       9       6
# 1         6      51      25
# 2         0      11       9
# 3        18      43      33
# 4        10      47      53
# ...     ...     ...     ...
# 99995    11      45      34
# 99996    22      29       1
# 99997    15       6      28
# 99998     8      36       7
# 99999    16      49      18
#
# [100000 rows x 6 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# Label encode categorical columns
encoder = LabelEncoder()
for col in ['file_name', 'access_type', 'user']:  
    X[col] = encoder.fit_transform(X[col])

# %%
X
# Out:
#        file_name  access_type  user  hour  minute  second
# 0              4            5     1    15       9       6
# 1              3            1     5     6      51      25
# 2              0            4     3     0      11       9
# 3              3            1     4    18      43      33
# 4              2            5     4    10      47      53
# ...          ...          ...   ...   ...     ...     ...
# 99995          5            2     0    11      45      34
# 99996          1            1     1    22      29       1
# 99997          7            0     1    15       6      28
# 99998          3            2     5     8      36       7
# 99999          5            3     2    16      49      18
#
# [100000 rows x 6 columns]

# %%
Y= encoder.fit_transform(Y)

# %%
Y
# Out:
# array([8, 8, 8, ..., 7, 4, 5])

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X = scaler.fit_transform(X)  # Normalize all numerical features

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
  X,Y , random_state=104,test_size=0.25, shuffle=True)

# %%
import numpy as np

seq_length = 10  # Define the sequence length
feature_dim = X_train.shape[1]  # Number of features

# Reshape data for LSTM using a sliding window approach
X_train_reshaped = np.array([X_train[i: i + seq_length] for i in range(len(X_train) - seq_length)])

# Adjust labels accordingly
y_train_reshaped = np.array(y_train[seq_length:])

# Check shape
print("X_train shape:", X_train_reshaped.shape)  # Expected: (samples, seq_length, feature_dim)
print("y_train shape:", y_train_reshaped.shape)
# Out:
# X_train shape: (74990, 10, 6)
# y_train shape: (74990,)

# %%
df["label"].nunique()
X.shape
# Out:
# (100000, 6)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

# Define Model
model = Sequential([
    LSTM(128, return_sequences=True, input_shape=(seq_length, feature_dim)),
    Dropout(0.2),
    LSTM(64, return_sequences=False),
    Dropout(0.2),
    Dense(32, activation='relu'),
    Dense(13, activation='softmax')  # Use 'sigmoid' for binary classification
])

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# Out:
# c:\Users\Asus\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
from tensorflow.keras.utils import to_categorical

# Convert integer labels to categorical (one-hot)
y_train_reshaped = to_categorical(y_train_reshaped, num_classes=13)

# %%
print("X_train shape:", X_train_reshaped.shape)  # Expected: (num_samples, seq_length, feature_dim)
print("y_train shape:", y_train_reshaped.shape)  # Expected: (num_samples, num_classes)
# Out:
# X_train shape: (74990, 10, 6)
# y_train shape: (74990, 13)

# %%
history = model.fit(X_train_reshaped, y_train_reshaped, epochs=50, batch_size=32)
# Out:
# Epoch 1/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 30s 11ms/step - accuracy: 0.8390 - loss: 0.8297
# Epoch 2/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 27s 11ms/step - accuracy: 0.8508 - loss: 0.7303
# Epoch 3/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 28s 12ms/step - accuracy: 0.8505 - loss: 0.7284
# Epoch 4/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 30s 13ms/step - accuracy: 0.8513 - loss: 0.7250
# Epoch 5/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 28s 12ms/step - accuracy: 0.8513 - loss: 0.7240
# Epoch 6/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 27s 12ms/step - accuracy: 0.8505 - loss: 0.7273
# Epoch 7/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 30s 13ms/step - accuracy: 0.8507 - loss: 0.7297
# Epoch 8/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 31s 13ms/step - accuracy: 0.8485 - loss: 0.7364
# Epoch 9/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 30s 13ms/step - accuracy: 0.8485 - loss: 0.7346
# Epoch 10/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 30s 13ms/step - accuracy: 0.8499 - loss: 0.7311
# Epoch 11/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 31s 13ms/step - accuracy: 0.8489 - loss: 0.7318
# Epoch 12/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 30s 13ms/step - accuracy: 0.8495 - loss: 0.7296
# Epoch 13/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 29s 12ms/step - accuracy: 0.8492 - loss: 0.7302
# Epoch 14/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 31s 13ms/step - accuracy: 0.8500 - loss: 0.7269
# Epoch 15/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 30s 13ms/step - accuracy: 0.8490 - loss: 0.7303
# Epoch 16/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 28s 12ms/step - accuracy: 0.8516 - loss: 0.7208
# Epoch 17/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 31s 13ms/step - accuracy: 0.8503 - loss: 0.7264
# Epoch 18/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 25s 10ms/step - accuracy: 0.8507 - loss: 0.7248
# Epoch 19/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 26s 11ms/step - accuracy: 0.8504 - loss: 0.7258
# Epoch 20/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 26s 11ms/step - accuracy: 0.8510 - loss: 0.7228
# Epoch 21/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 26s 11ms/step - accuracy: 0.8511 - loss: 0.7223
# Epoch 22/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 26s 11ms/step - accuracy: 0.8496 - loss: 0.7286
# Epoch 23/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 24s 10ms/step - accuracy: 0.8493 - loss: 0.7298
# Epoch 24/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 25s 11ms/step - accuracy: 0.8506 - loss: 0.7247
# Epoch 25/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 26s 11ms/step - accuracy: 0.8500 - loss: 0.7269
# Epoch 26/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 26s 11ms/step - accuracy: 0.8509 - loss: 0.7232
# Epoch 27/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 28s 12ms/step - accuracy: 0.8495 - loss: 0.7291
# Epoch 28/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 27s 12ms/step - accuracy: 0.8508 - loss: 0.7239
# Epoch 29/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 39s 17ms/step - accuracy: 0.8507 - loss: 0.7242
# Epoch 30/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 46s 20ms/step - accuracy: 0.8515 - loss: 0.7212
# Epoch 31/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 44s 19ms/step - accuracy: 0.8517 - loss: 0.7212
# Epoch 32/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 44s 19ms/step - accuracy: 0.8522 - loss: 0.7191
# Epoch 33/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 46s 20ms/step - accuracy: 0.8504 - loss: 0.7245
# Epoch 34/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 44s 19ms/step - accuracy: 0.8489 - loss: 0.7299
# Epoch 35/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 44s 19ms/step - accuracy: 0.8502 - loss: 0.7263
# Epoch 36/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 48s 20ms/step - accuracy: 0.8506 - loss: 0.7243
# Epoch 37/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 46s 20ms/step - accuracy: 0.8501 - loss: 0.7247
# Epoch 38/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 45s 19ms/step - accuracy: 0.8505 - loss: 0.7237
# Epoch 39/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 47s 20ms/step - accuracy: 0.8491 - loss: 0.7290
# Epoch 40/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 44s 19ms/step - accuracy: 0.8501 - loss: 0.7244
# Epoch 41/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 40s 17ms/step - accuracy: 0.8516 - loss: 0.7189
# Epoch 42/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 42s 18ms/step - accuracy: 0.8501 - loss: 0.7249
# Epoch 43/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 44s 19ms/step - accuracy: 0.8514 - loss: 0.7219
# Epoch 44/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 44s 19ms/step - accuracy: 0.8511 - loss: 0.7212
# Epoch 45/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 44s 19ms/step - accuracy: 0.8527 - loss: 0.7145
# Epoch 46/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 43s 18ms/step - accuracy: 0.8516 - loss: 0.7181
# Epoch 47/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 41s 17ms/step - accuracy: 0.8481 - loss: 0.7312
# Epoch 48/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 40s 17ms/step - accuracy: 0.8492 - loss: 0.7270
# Epoch 49/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 41s 17ms/step - accuracy: 0.8490 - loss: 0.7267
# Epoch 50/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 41s 17ms/step - accuracy: 0.8494 - loss: 0.7241

# %%
import matplotlib.pyplot as plt

# Count occurrences of each label
label_counts = df['label'].value_counts()

# Plot the distribution
plt.figure(figsize=(10, 5))
label_counts.plot(kind='bar', color=['blue', 'red', 'green', 'orange', 'purple'])
plt.xlabel("Labels")
plt.ylabel("Count")
plt.title("Distribution of Labels in file Logs")
plt.xticks(rotation=45)
plt.show()

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense, Dropout
from tensorflow.keras.utils import to_categorical

# Define RNN Model
model_rnn = Sequential([
    SimpleRNN(128, return_sequences=True, input_shape=(seq_length, feature_dim)),
    Dropout(0.2),
    SimpleRNN(64, return_sequences=False),
    Dropout(0.2),
    Dense(32, activation='relu'),
    Dense(13, activation='softmax')  # Adjust for the number of classes
])

model_rnn.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

print(model_rnn.summary())

# Reshape X_test for RNN Evaluation
X_test_reshaped = np.array([X_test[i: i + seq_length] for i in range(len(X_test) - seq_length)])
y_test_reshaped = np.array(y_test[seq_length:])

# One-hot encode y_test_reshaped to match the model's expected output
y_test_reshaped = to_categorical(y_test_reshaped, num_classes=13)

# Train the RNN model
history_rnn = model_rnn.fit(X_train_reshaped, y_train_reshaped, epochs=50, batch_size=32)

# Evaluate the RNN model
loss, accuracy = model_rnn.evaluate(X_test_reshaped, y_test_reshaped, batch_size=32)
print(f"Test Loss: {loss}, Test Accuracy: {accuracy}")
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn_2 (SimpleRNN)        │ (None, 10, 128)        │        17,280 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 10, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_3 (SimpleRNN)        │ (None, 64)             │        12,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 13)             │           429 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 32,141 (125.55 KB)
#  Trainable params: 32,141 (125.55 KB)
#  Non-trainable params: 0 (0.00 B)
# None
# Epoch 1/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 49s 14ms/step - accuracy: 0.8132 - loss: 0.8516
# Epoch 2/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 33s 14ms/step - accuracy: 0.8476 - loss: 0.7451
# Epoch 3/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 33s 14ms/step - accuracy: 0.8488 - loss: 0.7384
# Epoch 4/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 34s 14ms/step - accuracy: 0.8517 - loss: 0.7236
# Epoch 5/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 25s 11ms/step - accuracy: 0.8510 - loss: 0.7282
# Epoch 6/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 28s 12ms/step - accuracy: 0.8514 - loss: 0.7343
# Epoch 7/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 28s 12ms/step - accuracy: 0.8508 - loss: 0.7298
# Epoch 8/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 28s 12ms/step - accuracy: 0.8513 - loss: 0.7262
# Epoch 9/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 28s 12ms/step - accuracy: 0.8493 - loss: 0.7335
# Epoch 10/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 28s 12ms/step - accuracy: 0.8518 - loss: 0.7228
# Epoch 11/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 32s 13ms/step - accuracy: 0.8479 - loss: 0.7375
# Epoch 12/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 58s 25ms/step - accuracy: 0.8502 - loss: 0.7275
# Epoch 13/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 23s 10ms/step - accuracy: 0.8491 - loss: 0.7317
# Epoch 14/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 27s 12ms/step - accuracy: 0.8527 - loss: 0.7180
# Epoch 15/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 31s 13ms/step - accuracy: 0.8508 - loss: 0.7242
# Epoch 16/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 34s 14ms/step - accuracy: 0.8506 - loss: 0.7255
# Epoch 17/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 38s 13ms/step - accuracy: 0.8487 - loss: 0.7326
# Epoch 18/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 31s 13ms/step - accuracy: 0.8516 - loss: 0.7210
# Epoch 19/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 27s 11ms/step - accuracy: 0.8501 - loss: 0.7275
# Epoch 20/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 22s 9ms/step - accuracy: 0.8495 - loss: 0.7288
# Epoch 21/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 28s 12ms/step - accuracy: 0.8509 - loss: 0.7237
# Epoch 22/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 28s 12ms/step - accuracy: 0.8492 - loss: 0.7307
# Epoch 23/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 29s 12ms/step - accuracy: 0.8525 - loss: 0.7174
# Epoch 24/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 28s 12ms/step - accuracy: 0.8485 - loss: 0.7334
# Epoch 25/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 31s 13ms/step - accuracy: 0.8499 - loss: 0.7282
# Epoch 26/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 30s 13ms/step - accuracy: 0.8516 - loss: 0.7214
# Epoch 27/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 28s 12ms/step - accuracy: 0.8517 - loss: 0.7216
# Epoch 28/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 29s 12ms/step - accuracy: 0.8489 - loss: 0.7305
# Epoch 29/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 29s 12ms/step - accuracy: 0.8530 - loss: 0.7164
# Epoch 30/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 30s 13ms/step - accuracy: 0.8522 - loss: 0.7190
# Epoch 31/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 29s 13ms/step - accuracy: 0.8491 - loss: 0.7305
# Epoch 32/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 29s 12ms/step - accuracy: 0.8488 - loss: 0.7312
# Epoch 33/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 25s 11ms/step - accuracy: 0.8508 - loss: 0.7233
# Epoch 34/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 23s 10ms/step - accuracy: 0.8477 - loss: 0.7343
# Epoch 35/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 22s 9ms/step - accuracy: 0.8491 - loss: 0.7306
# Epoch 36/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 22s 9ms/step - accuracy: 0.8504 - loss: 0.7258
# Epoch 37/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 21s 9ms/step - accuracy: 0.8516 - loss: 0.7207
# Epoch 38/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 22s 9ms/step - accuracy: 0.8541 - loss: 0.7118
# Epoch 39/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 22s 9ms/step - accuracy: 0.8509 - loss: 0.7241
# Epoch 40/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 23s 10ms/step - accuracy: 0.8509 - loss: 0.7242
# Epoch 41/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 22s 9ms/step - accuracy: 0.8516 - loss: 0.7214
# Epoch 42/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 23s 10ms/step - accuracy: 0.8480 - loss: 0.7338
# Epoch 43/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 380s 162ms/step - accuracy: 0.8509 - loss: 0.7236
# Epoch 44/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 22s 10ms/step - accuracy: 0.8491 - loss: 0.7300
# Epoch 45/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 28s 12ms/step - accuracy: 0.8521 - loss: 0.7182
# Epoch 46/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 24s 10ms/step - accuracy: 0.8491 - loss: 0.7289
# Epoch 47/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 21s 9ms/step - accuracy: 0.8509 - loss: 0.7237
# Epoch 48/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 20s 8ms/step - accuracy: 0.8505 - loss: 0.7234
# Epoch 49/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 21s 9ms/step - accuracy: 0.8525 - loss: 0.7172
# Epoch 50/50
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 20s 9ms/step - accuracy: 0.8508 - loss: 0.7234
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8460 - loss: 0.7431
# Test Loss: 0.731486439704895, Test Accuracy: 0.8488595485687256
