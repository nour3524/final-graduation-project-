# %%
import pandas as pd

# %%
df = pd.read_csv("data/network_logs.csv")
df.head()
# Out:
#              timestamp       local_ip  local_port      remote_ip  remote_port  \
# 0  2025-01-01T00:00:10  192.168.1.181       36818   192.168.1.30         8080
# 1  2025-01-01T00:00:20  192.168.1.212       55824   192.168.1.92         3389
# 2  2025-01-01T00:00:30  192.168.1.144       65351  192.168.1.101           22
# 3  2025-01-01T00:00:40   192.168.1.68       18887  192.168.1.121         8080
# 4  2025-01-01T00:00:50   192.168.1.29       35759  192.168.1.185           22
#
#   protocol  blacklisted   label                   reason
# 0      TCP        False  benign  Normal network activity
# 1      TCP        False  benign  Normal network activity
# 2      UDP        False  benign  Normal network activity
# 3      TCP        False  benign  Normal network activity
# 4      TCP        False  benign  Normal network activity

# %%
df['label'] = df.apply(lambda row: 'benign' if row['label'] == 'benign' else row['reason'], axis=1)

# %%
df.tail(50)
# Out:
#                   timestamp       local_ip  local_port      remote_ip  \
# 299950  2025-02-04T17:11:50  192.168.1.206        1673  192.168.1.233
# 299951  2025-02-04T17:12:00  192.168.1.232       30889  192.168.1.154
# 299952  2025-02-04T17:12:10   192.168.1.18       12721  192.168.1.169
# 299953  2025-02-04T17:12:20  192.168.1.185        2567   192.168.1.41
# 299954  2025-02-04T17:12:30  192.168.1.203       11098  192.168.1.202
# 299955  2025-02-04T17:12:40    192.168.1.7       10230   192.168.1.39
# 299956  2025-02-04T17:12:50  192.168.1.236       35969   192.168.1.55
# 299957  2025-02-04T17:13:00   192.168.1.23       31998  192.168.1.216
# 299958  2025-02-04T17:13:10  192.168.1.189       35368  192.168.1.178
# 299959  2025-02-04T17:13:20  192.168.1.215       52319   192.168.1.20
# 299960  2025-02-04T17:13:30  192.168.1.103       55808  192.168.1.249
# 299961  2025-02-04T17:13:40   192.168.1.94       56966  192.168.1.184
# 299962  2025-02-04T17:13:50  192.168.1.239        9683  192.168.1.197
# 299963  2025-02-04T17:14:00  192.168.1.178       28018  192.168.1.185
# 299964  2025-02-04T17:14:10   192.168.1.99       64684  192.168.1.158
# 299965  2025-02-04T17:14:20  192.168.1.114       34781  192.168.1.207
# 299966  2025-02-04T17:14:30  192.168.1.145       37056   192.168.1.51
# 299967  2025-02-04T17:14:40   192.168.1.80       17476   192.168.1.69
# 299968  2025-02-04T17:14:50  192.168.1.100       24204   192.168.1.30
# 299969  2025-02-04T17:15:00  192.168.1.110       21853  192.168.1.175
# 299970  2025-02-04T17:15:10   192.168.1.84       51163   192.168.1.79
# 299971  2025-02-04T17:15:20  192.168.1.177       58110  192.168.1.242
# 299972  2025-02-04T17:15:30   192.168.1.68       17634  192.168.1.235
# 299973  2025-02-04T17:15:40   192.168.1.87       55170   192.168.1.85
# 299974  2025-02-04T17:15:50  192.168.1.172       44104  192.168.1.133
# 299975  2025-02-04T17:16:00  192.168.1.177       24551   192.168.1.14
# 299976  2025-02-04T17:16:10  192.168.1.113       17649  192.168.1.179
# 299977  2025-02-04T17:16:20  192.168.1.240       43357  192.168.1.208
# 299978  2025-02-04T17:16:30   192.168.1.99       50552  192.168.1.203
# 299979  2025-02-04T17:16:40   192.168.1.61       48171   192.168.1.37
# 299980  2025-02-04T17:16:50   192.168.1.90       23885   192.168.1.13
# 299981  2025-02-04T17:17:00  192.168.1.145       44630  192.168.1.113
# 299982  2025-02-04T17:17:10  192.168.1.218       21980   192.168.1.19
# 299983  2025-02-04T17:17:20  192.168.1.140       17246   192.168.1.45
# 299984  2025-02-04T17:17:30   192.168.1.18       56859  192.168.1.116
# 299985  2025-02-04T17:17:40    192.168.1.4       13569  192.168.1.138
# 299986  2025-02-04T17:17:50   192.168.1.72       48187   192.168.1.38
# 299987  2025-02-04T17:18:00   192.168.1.13       46082   192.168.1.26
# 299988  2025-02-04T17:18:10  192.168.1.235       38416   192.168.1.35
# 299989  2025-02-04T17:18:20   192.168.1.33       21780  192.168.1.209
# 299990  2025-02-04T17:18:30  192.168.1.164       35575  192.168.1.120
# 299991  2025-02-04T17:18:40    192.168.1.5       24502  192.168.1.144
# 299992  2025-02-04T17:18:50  192.168.1.216       40794   192.168.1.86
# 299993  2025-02-04T17:19:00   192.168.1.63       51666  192.168.1.214
# 299994  2025-02-04T17:19:10   192.168.1.13       55872  192.168.1.141
# 299995  2025-02-04T17:19:20  192.168.1.241       48870  192.168.1.125
# 299996  2025-02-04T17:19:30   192.168.1.87        7373    192.168.1.8
# 299997  2025-02-04T17:19:40  192.168.1.132       49916  192.168.1.250
# 299998  2025-02-04T17:19:50  192.168.1.126       18694  192.168.1.181
# 299999  2025-02-04T17:20:00   192.168.1.17       10283  192.168.1.198
#
#         remote_port protocol  blacklisted  \
# 299950           22      TCP        False
# 299951         3389      UDP        False
# 299952           22      UDP        False
# 299953           53      UDP        False
# 299954           53      UDP        False
# 299955         8080      UDP        False
# 299956         3389      UDP        False
# 299957           22      UDP        False
# 299958          443      UDP        False
# 299959           22      UDP        False
# 299960           22      UDP        False
# 299961           80      UDP        False
# 299962           53      UDP        False
# 299963          443      TCP        False
# 299964          443      TCP        False
# 299965         3389      TCP        False
# 299966           80      TCP        False
# 299967           53      UDP        False
# 299968           22      TCP        False
# 299969         3389      UDP        False
# 299970           22      UDP        False
# 299971           80      UDP        False
# 299972           53      TCP        False
# 299973           22      UDP        False
# 299974         3389      TCP        False
# 299975           53      UDP        False
# 299976          443      UDP        False
# 299977         3389      UDP        False
# 299978          443      TCP        False
# 299979         8080      TCP        False
# 299980           80      UDP        False
# 299981           22      TCP        False
# 299982          443      TCP        False
# 299983           22      TCP        False
# 299984         3389      TCP        False
# 299985          443      TCP        False
# 299986           22      UDP        False
# 299987         8080      TCP        False
# 299988         3389      UDP        False
# 299989          443      TCP        False
# 299990         3389      UDP        False
# 299991         8080      UDP        False
# 299992           53      TCP        False
# 299993           22      TCP        False
# 299994           53      UDP        False
# 299995          443      UDP        False
# 299996           53      UDP        False
# 299997           80      TCP        False
# 299998         8080      TCP        False
# 299999          443      TCP        False
#
#                                                     label  \
# 299950  Accessing external IPs outside normal working ...
# 299951  Unusual number of connections to cloud storage...
# 299952  Unusual number of connections to cloud storage...
# 299953                    Unusual outbound traffic volume
# 299954                    Unusual outbound traffic volume
# 299955  Unusual number of connections to cloud storage...
# 299956  Unusual number of connections to cloud storage...
# 299957   High number of DNS requests to untrusted domains
# 299958                Repeated failed connection attempts
# 299959                Repeated failed connection attempts
# 299960                    Unusual outbound traffic volume
# 299961                    Unusual outbound traffic volume
# 299962                    Unusual outbound traffic volume
# 299963                Repeated failed connection attempts
# 299964  Accessing external IPs outside normal working ...
# 299965   High number of DNS requests to untrusted domains
# 299966                    Unusual outbound traffic volume
# 299967                Repeated failed connection attempts
# 299968   High number of DNS requests to untrusted domains
# 299969   High number of DNS requests to untrusted domains
# 299970  Unusual number of connections to cloud storage...
# 299971  Unusual number of connections to cloud storage...
# 299972   High number of DNS requests to untrusted domains
# 299973                Repeated failed connection attempts
# 299974  Unusual number of connections to cloud storage...
# 299975  Accessing external IPs outside normal working ...
# 299976                Repeated failed connection attempts
# 299977                Repeated failed connection attempts
# 299978                    Unusual outbound traffic volume
# 299979  Accessing external IPs outside normal working ...
# 299980  Unusual number of connections to cloud storage...
# 299981                Repeated failed connection attempts
# 299982                    Unusual outbound traffic volume
# 299983                    Unusual outbound traffic volume
# 299984                Repeated failed connection attempts
# 299985  Accessing external IPs outside normal working ...
# 299986  Unusual number of connections to cloud storage...
# 299987  Unusual number of connections to cloud storage...
# 299988                    Unusual outbound traffic volume
# 299989                    Unusual outbound traffic volume
# 299990                Repeated failed connection attempts
# 299991   High number of DNS requests to untrusted domains
# 299992  Accessing external IPs outside normal working ...
# 299993   High number of DNS requests to untrusted domains
# 299994  Accessing external IPs outside normal working ...
# 299995   High number of DNS requests to untrusted domains
# 299996  Accessing external IPs outside normal working ...
# 299997                Repeated failed connection attempts
# 299998  Accessing external IPs outside normal working ...
# 299999  Accessing external IPs outside normal working ...
#
#                                                    reason
# 299950  Accessing external IPs outside normal working ...
# 299951  Unusual number of connections to cloud storage...
# 299952  Unusual number of connections to cloud storage...
# 299953                    Unusual outbound traffic volume
# 299954                    Unusual outbound traffic volume
# 299955  Unusual number of connections to cloud storage...
# 299956  Unusual number of connections to cloud storage...
# 299957   High number of DNS requests to untrusted domains
# 299958                Repeated failed connection attempts
# 299959                Repeated failed connection attempts
# 299960                    Unusual outbound traffic volume
# 299961                    Unusual outbound traffic volume
# 299962                    Unusual outbound traffic volume
# 299963                Repeated failed connection attempts
# 299964  Accessing external IPs outside normal working ...
# 299965   High number of DNS requests to untrusted domains
# 299966                    Unusual outbound traffic volume
# 299967                Repeated failed connection attempts
# 299968   High number of DNS requests to untrusted domains
# 299969   High number of DNS requests to untrusted domains
# 299970  Unusual number of connections to cloud storage...
# 299971  Unusual number of connections to cloud storage...
# 299972   High number of DNS requests to untrusted domains
# 299973                Repeated failed connection attempts
# 299974  Unusual number of connections to cloud storage...
# 299975  Accessing external IPs outside normal working ...
# 299976                Repeated failed connection attempts
# 299977                Repeated failed connection attempts
# 299978                    Unusual outbound traffic volume
# 299979  Accessing external IPs outside normal working ...
# 299980  Unusual number of connections to cloud storage...
# 299981                Repeated failed connection attempts
# 299982                    Unusual outbound traffic volume
# 299983                    Unusual outbound traffic volume
# 299984                Repeated failed connection attempts
# 299985  Accessing external IPs outside normal working ...
# 299986  Unusual number of connections to cloud storage...
# 299987  Unusual number of connections to cloud storage...
# 299988                    Unusual outbound traffic volume
# 299989                    Unusual outbound traffic volume
# 299990                Repeated failed connection attempts
# 299991   High number of DNS requests to untrusted domains
# 299992  Accessing external IPs outside normal working ...
# 299993   High number of DNS requests to untrusted domains
# 299994  Accessing external IPs outside normal working ...
# 299995   High number of DNS requests to untrusted domains
# 299996  Accessing external IPs outside normal working ...
# 299997                Repeated failed connection attempts
# 299998  Accessing external IPs outside normal working ...
# 299999  Accessing external IPs outside normal working ...

# %%
X = df.iloc[:, :-2]

Y = df["label"]

# %%
import pandas as pd

# Convert timestamp column to datetime format
X['timestamp'] = pd.to_datetime(X['timestamp'])

# Extract meaningful time-based features
X['hour'] = X['timestamp'].dt.hour  # Hour of the day (0-23)
X['minute'] = X['timestamp'].dt.minute  # Minute of the hour (0-59)
X['second'] = X['timestamp'].dt.second  # Second of the minute (0-59)


# Drop the original timestamp column (since it’s now numeric)
X = X.drop(columns=['timestamp'])

# %%
X
# Out:
#              local_ip  local_port      remote_ip  remote_port protocol  \
# 0       192.168.1.181       36818   192.168.1.30         8080      TCP
# 1       192.168.1.212       55824   192.168.1.92         3389      TCP
# 2       192.168.1.144       65351  192.168.1.101           22      UDP
# 3        192.168.1.68       18887  192.168.1.121         8080      TCP
# 4        192.168.1.29       35759  192.168.1.185           22      TCP
# ...               ...         ...            ...          ...      ...
# 299995  192.168.1.241       48870  192.168.1.125          443      UDP
# 299996   192.168.1.87        7373    192.168.1.8           53      UDP
# 299997  192.168.1.132       49916  192.168.1.250           80      TCP
# 299998  192.168.1.126       18694  192.168.1.181         8080      TCP
# 299999   192.168.1.17       10283  192.168.1.198          443      TCP
#
#         blacklisted  hour  minute  second
# 0             False     0       0      10
# 1             False     0       0      20
# 2             False     0       0      30
# 3             False     0       0      40
# 4             False     0       0      50
# ...             ...   ...     ...     ...
# 299995        False    17      19      20
# 299996        False    17      19      30
# 299997        False    17      19      40
# 299998        False    17      19      50
# 299999        False    17      20       0
#
# [300000 rows x 9 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# Label encode categorical columns
encoder = LabelEncoder()
for col in ['protocol', 'local_ip', 'remote_ip']:  
    X[col] = encoder.fit_transform(X[col])

# Convert blacklisted (True/False) to integer (1/0)
X['blacklisted'] = X['blacklisted'].astype(int)

# %%
X
# Out:
#         local_ip  local_port  remote_ip  remote_port  protocol  blacklisted  \
# 0             90       36818        178         8080         0            0
# 1            125       55824        246         3389         0            0
# 2             49       65351          3           22         1            0
# 3            218       18887         25         8080         0            0
# 4            175       35759         95           22         0            0
# ...          ...         ...        ...          ...       ...          ...
# 299995       157       48870         29          443         1            0
# 299996       239        7373        232           53         1            0
# 299997        36       49916        168           80         0            0
# 299998        29       18694         91         8080         0            0
# 299999        77       10283        109          443         0            0
#
#         hour  minute  second
# 0          0       0      10
# 1          0       0      20
# 2          0       0      30
# 3          0       0      40
# 4          0       0      50
# ...      ...     ...     ...
# 299995    17      19      20
# 299996    17      19      30
# 299997    17      19      40
# 299998    17      19      50
# 299999    17      20       0
#
# [300000 rows x 9 columns]

# %%
Y= encoder.fit_transform(Y)

# %%
Y
# Out:
# array([12, 12, 12, ...,  8,  0,  0])

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X = scaler.fit_transform(X)  # Normalize all numerical features

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
  X,Y , random_state=104,test_size=0.25, shuffle=True)

# %%
import numpy as np

seq_length = 10  # Define the sequence length
feature_dim = X_train.shape[1]  # Number of features

# Reshape data for LSTM using a sliding window approach
X_train_reshaped = np.array([X_train[i: i + seq_length] for i in range(len(X_train) - seq_length)])

# Adjust labels accordingly
y_train_reshaped = np.array(y_train[seq_length:])

# Check shape
print("X_train shape:", X_train_reshaped.shape)  # Expected: (samples, seq_length, feature_dim)
print("y_train shape:", y_train_reshaped.shape)
# Out:
# X_train shape: (224990, 10, 9)
# y_train shape: (224990,)

# %%
df["label"].nunique()
X.shape
# Out:
# (300000, 9)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

# Define Model
model = Sequential([
    LSTM(128, return_sequences=True, input_shape=(seq_length, feature_dim)),
    Dropout(0.2),
    LSTM(64, return_sequences=False),
    Dropout(0.2),
    Dense(32, activation='relu'),
    Dense(13, activation='softmax')  # Use 'sigmoid' for binary classification
])

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# Out:
# c:\Users\Asus\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
from tensorflow.keras.utils import to_categorical

# Convert integer labels to categorical (one-hot)
y_train_reshaped = to_categorical(y_train_reshaped, num_classes=13)

# %%
print("X_train shape:", X_train_reshaped.shape)  # Expected: (num_samples, seq_length, feature_dim)
print("y_train shape:", y_train_reshaped.shape)  # Expected: (num_samples, num_classes)
# Out:
# X_train shape: (224990, 10, 9)
# y_train shape: (224990, 13)

# %%
history = model.fit(X_train_reshaped, y_train_reshaped, epochs=50, batch_size=32)
# Out:
# Epoch 1/50
# 7031/7031 ━━━━━━━━━━━━━━━━━━━━ 116s 16ms/step - accuracy: 0.8456 - loss: 0.8361
# Epoch 2/50
# 7031/7031 ━━━━━━━━━━━━━━━━━━━━ 117s 17ms/step - accuracy: 0.8508 - loss: 0.7951
# Epoch 3/50
# 7031/7031 ━━━━━━━━━━━━━━━━━━━━ 157s 22ms/step - accuracy: 0.8507 - loss: 0.7944
# Epoch 4/50
# 7031/7031 ━━━━━━━━━━━━━━━━━━━━ 166s 24ms/step - accuracy: 0.8509 - loss: 0.7922
# Epoch 5/50
# 7031/7031 ━━━━━━━━━━━━━━━━━━━━ 169s 24ms/step - accuracy: 0.8497 - loss: 0.7960
# Epoch 6/50
# 7031/7031 ━━━━━━━━━━━━━━━━━━━━ 157s 22ms/step - accuracy: 0.8498 - loss: 0.7950
# Epoch 7/50
# 7031/7031 ━━━━━━━━━━━━━━━━━━━━ 152s 22ms/step - accuracy: 0.8512 - loss: 0.7891
# Epoch 8/50
# 7031/7031 ━━━━━━━━━━━━━━━━━━━━ 147s 21ms/step - accuracy: 0.8505 - loss: 0.7919
# Epoch 9/50
# 7031/7031 ━━━━━━━━━━━━━━━━━━━━ 153s 22ms/step - accuracy: 0.8514 - loss: 0.7885
# Epoch 10/50
# 7031/7031 ━━━━━━━━━━━━━━━━━━━━
50
# 7031/7031 ━━━━━━━━━━━━━━━━━━━━ 70s 10ms/step - accuracy: 0.8508 - loss: 0.7893
# Epoch 47/50
# 7031/7031 ━━━━━━━━━━━━━━━━━━━━ 72s 10ms/step - accuracy: 0.8520 - loss: 0.7847
# Epoch 48/50
# 7031/7031 ━━━━━━━━━━━━━━━━━━━━ 69s 10ms/step - accuracy: 0.8498 - loss: 0.7941
# Epoch 49/50
# 7031/7031 ━━━━━━━━━━━━━━━━━━━━ 71s 10ms/step - accuracy: 0.8506 - loss: 0.7902
# Epoch 50/50
# 7031/7031 ━━━━━━━━━━━━━━━━━━━━ 76s 11ms/step - accuracy: 0.8494 - loss: 0.7954

# %%
import matplotlib.pyplot as plt

# Count occurrences of each label
label_counts = df['label'].value_counts()

# Plot the distribution
plt.figure(figsize=(10, 5))
label_counts.plot(kind='bar', color=['blue', 'red', 'green', 'orange', 'purple'])
plt.xlabel("Labels")
plt.ylabel("Count")
plt.title("Distribution of Labels in Network Logs")
plt.xticks(rotation=45)
plt.show()

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense, Dropout
from tensorflow.keras.utils import to_categorical

# Define RNN Model
model_rnn = Sequential([
    SimpleRNN(128, return_sequences=True, input_shape=(seq_length, feature_dim)),
    Dropout(0.2),
    SimpleRNN(64, return_sequences=False),
    Dropout(0.2),
    Dense(32, activation='relu'),
    Dense(13, activation='softmax')  # Adjust to the number of classes
])

model_rnn.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
print(model_rnn.summary())

# Reshape X_test for RNN
X_test_reshaped = np.array([X_test[i: i + seq_length] for i in range(len(X_test) - seq_length)])
y_test_reshaped = y_test[seq_length:]

# One-hot encode test labels if not already
y_test_reshaped = to_categorical(y_test_reshaped, num_classes=13)

# Train the RNN model
history_rnn = model_rnn.fit(X_train_reshaped, y_train_reshaped, epochs=50, batch_size=32)

# Evaluate the RNN model
loss, accuracy = model_rnn.evaluate(X_test_reshaped, y_test_reshaped, batch_size=32)
print(f"Test Loss: {loss}, Test Accuracy: {accuracy}")
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn_2 (SimpleRNN)        │ (None, 10, 128)        │        17,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 10, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_3 (SimpleRNN)        │ (None, 64)             │        12,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 13)             │           429 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 32,525 (127.05 KB)
#  Trainable params: 32,525 (127.05 KB)
#  Non-trainable params: 0 (0.00 B)
# None
# Epoch 1/50
# 7031/7031 ━━━━━━━━━━━━━━━━━━━━ 98s 13ms/step - accuracy: 0.8364 - loss: 0.8537
# Epoch 2/50
# 7031/7031 ━━━━━━━━━━━━━━━━━━━━ 92s 13ms/step - accuracy: 0.8514 - loss: 0.7959
# Epoch 3/50
# 7031/7031 ━━━━━━━━━━━━━━━━━━━━ 82s 12ms/step - accuracy: 0.8497 - loss: 0.8006
# Epoch 4/50
# 7031/7031 ━━━━━━━━━━━━━━━━━━━━ 86s 12ms/step - accuracy: 0.8509 - loss: 0.7949
# Epoch 5/50
# 7031/7031 ━━━━━━━━━━━━━━━━━━━━ 178s 13ms/step - accuracy: 0.8496 - loss: 0.7996
# Epoch 6/50
# 7031/7031 ━━━━━━━━━━━━━━━━━━━━ 87s 12ms/step - accuracy: 0.8508 - loss: 0.7939
# Epoch 7/50
# 7031/7031 ━━━━━━━━━━━━━━━━━━━━ 74s 11ms/step - accuracy: 0.8504 - loss: 0.7948
# Epoch 8/50
# 7031/7031 ━━━━━━━━━━━━━━━━━━━━ 86s 12ms/step - accuracy: 0.8499 - loss: 0.7969
# Epoch 9/50
# 7031/7031 ━━━━━━━━━━━━━━━━━━━━ 86s 12ms/step - accuracy: 0.8508 - loss: 0.7925
# Epoch 10/50
# 7031/7031 ━━━━━━━━━━━━━━━━━━━━ 86s 12ms/step - accuracy: 0.8499 - loss: 0.7956
# Epoch 11/50
# 7031/7031 ━━━━━━━━━━━━━━━━━━━━ 78s 11ms/step - accuracy: 0.8512 - loss: 0.7913
# Epoch 12/50
# 7031/7031 ━━━━━━━━━━━━━━━━━━━━ 64s 9ms/step - accuracy: 0.8502 - loss: 0.7944
# Epoch 13/50
# 7031/7031 ━━━━━━━━━━━━━━━━━━━━ 65s 9ms/step - accuracy: 0.8512 - loss: 0.7898
# Epoch 14/50
# 7031/7031 ━━━━━━━━━━━━━━━━━━━━ 426s 61ms/step - accuracy: 0.8490 - loss: 0.7991
# Epoch 15/50
# 7031/7031 ━━━━━━━━━━━━━━━━━━━━ 69s 10ms/step - accuracy: 0.8506 - loss: 0.7924
# Epoch 16/50
# 7031/7031 ━━━━━━━━━━━━━━━━━━━━